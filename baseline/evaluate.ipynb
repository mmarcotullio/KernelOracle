# %%
# !pip install -r requirements.txt
# Out:
# Collecting torch (from -r requirements.txt (line 1))
#   Using cached torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting torchvision (from -r requirements.txt (line 2))
#   Using cached torchvision-0.17.2-cp310-cp310-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Collecting torchaudio (from -r requirements.txt (line 3))
#   Using cached torchaudio-2.2.2-cp310-cp310-macosx_10_13_x86_64.whl.metadata (6.4 kB)
# Collecting numpy==1.24.4 (from -r requirements.txt (line 4))
#   Using cached numpy-1.24.4-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.6 kB)
# Collecting pandas (from -r requirements.txt (line 5))
#   Downloading pandas-2.3.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (91 kB)
# Collecting matplotlib (from -r requirements.txt (line 6))
#   Using cached matplotlib-3.10.8-cp310-cp310-macosx_10_12_x86_64.whl.metadata (52 kB)
# Collecting scikit-learn (from -r requirements.txt (line 7))
#   Downloading scikit_learn-1.7.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Collecting tqdm (from -r requirements.txt (line 8))
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting torchviz (from -r requirements.txt (line 9))
#   Using cached torchviz-0.0.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting graphviz (from -r requirements.txt (line 10))
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting filelock (from torch->-r requirements.txt (line 1))
#   Downloading filelock-3.24.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Collecting sympy (from torch->-r requirements.txt (line 1))
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch->-r requirements.txt (line 1))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->-r requirements.txt (line 1))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch->-r requirements.txt (line 1))
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision->-r requirements.txt (line 2))
#   Downloading pillow-12.1.1-cp310-cp310-macosx_10_10_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->-r requirements.txt (line 5))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r requirements.txt (line 5))
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r requirements.txt (line 6))
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->-r requirements.txt (line 6))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r requirements.txt (line 6))
#   Downloading fonttools-4.61.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r requirements.txt (line 6))
#   Downloading kiwisolver-1.4.9-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (26.0)
# Collecting pyparsing>=3 (from matplotlib->-r requirements.txt (line 6))
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting scipy>=1.8.0 (from scikit-learn->-r requirements.txt (line 7))
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements.txt (line 7))
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r requirements.txt (line 7))
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.17.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->-r requirements.txt (line 1))
#   Downloading markupsafe-3.0.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (2.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch->-r requirements.txt (line 1))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached numpy-1.24.4-cp310-cp310-macosx_10_9_x86_64.whl (19.8 MB)
# Using cached torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl (150.8 MB)
# Using cached torchvision-0.17.2-cp310-cp310-macosx_10_13_x86_64.whl (1.7 MB)
# Using cached torchaudio-2.2.2-cp310-cp310-macosx_10_13_x86_64.whl (3.4 MB)
# Downloading pandas-2.3.3-cp310-cp310-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 36.8 MB/s  0:00:00eta 0:00:01
# Using cached matplotlib-3.10.8-cp310-cp310-macosx_10_12_x86_64.whl (8.2 MB)
# Downloading scikit_learn-1.7.2-cp310-cp310-macosx_10_9_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 23.2 MB/s  0:00:00 eta 0:00:01
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached torchviz-0.0.3-py3-none-any.whl (5.7 kB)
# Using cached graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (268 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp310-cp310-macosx_10_9_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 35.4 MB/s  0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.4.9-cp310-cp310-macosx_10_9_x86_64.whl (66 kB)
# Downloading pillow-12.1.1-cp310-cp310-macosx_10_10_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 35.5 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_x86_64.whl (25.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 46.5 MB/s  0:00:00 eta 0:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading filelock-3.24.3-py3-none-any.whl (24 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp310-cp310-macosx_10_9_x86_64.whl (11 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: pytz, mpmath, tzdata, tqdm, threadpoolctl, sympy, pyparsing, pillow, numpy, networkx, MarkupSafe, kiwisolver, joblib, graphviz, fsspec, fonttools, filelock, cycler, scipy, pandas, jinja2, contourpy, torch, scikit-learn, matplotlib, torchviz, torchvision, torchaudio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/28 [torchaudio]8 [torchaudio]]]
# Successfully installed MarkupSafe-3.0.3 contourpy-1.3.2 cycler-0.12.1 filelock-3.24.3 fonttools-4.61.1 fsspec-2026.2.0 graphviz-0.21 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.4.9 matplotlib-3.10.8 mpmath-1.3.0 networkx-3.4.2 numpy-1.24.4 pandas-2.3.3 pillow-12.1.1 pyparsing-3.3.2 pytz-2025.2 scikit-learn-1.7.2 scipy-1.15.3 sympy-1.14.0 threadpoolctl-3.6.0 torch-2.2.2 torchaudio-2.2.2 torchvision-0.17.2 torchviz-0.0.3 tqdm-4.67.3 tzdata-2025.3

# %%
import time
import torch
import numpy as np
import pandas as pd
import utils
import model

# %%
MODEL_PATH = "model.pt"
DATA_PATH = "../data/scheduling_data_out_ab_nginx.csv"

BATCH_SIZE = 984
HIDDEN_DIM = 51
FUTURE = 1000

device = utils.DEVICE

# %%
def task_prediction_accuracy(pred, target):
    """
    Computes classification accuracy of next-task prediction.
    """
    pred_task = pred[:, :, 1:]
    target_task = target[:, :, 1:]

    pred_labels = torch.argmax(pred_task, dim=2)
    true_labels = torch.argmax(target_task, dim=2)

    correct = (pred_labels == true_labels).float()
    return correct.mean().item()

# %%
print("Loading dataset...")
df = pd.read_csv(DATA_PATH)
df = utils.preprocess_data(df=df)
data = df.to_numpy(dtype=np.float32)

data_dim = data.shape[1]
total = data.shape[0]
remainder = total % BATCH_SIZE
data = data[:total - remainder, :]

data = data.reshape(BATCH_SIZE, data_dim, -1)
data = np.transpose(data, axes=(0, 2, 1))

train_x, train_y, test_x, test_y = utils.make_training_and_testing_set(
    data, percent_train=85.0
)

test_x = test_x.to(device=device, dtype=torch.float32)
test_y = test_y.to(device=device, dtype=torch.float32)

print("Train shape:", train_x.shape)
print("Test shape:", test_x.shape)
# Out:
# Loading dataset...
# Train shape: torch.Size([836, 1171, 28])
# Test shape: torch.Size([148, 1171, 28])

# %%
print("Loading trained model...")
seq = model.Sequence2(
    in_dim=data_dim,
    out_dim=data_dim,
    hidden_dim=HIDDEN_DIM
).to(device)

seq.load_state_dict(torch.load(MODEL_PATH, map_location=device))
seq.eval()
# Out:
# Loading trained model...
# Sequence2(
#   (lstm1): LSTMCell(28, 51)
#   (lstm2): LSTMCell(51, 51)
#   (linear): Linear(in_features=51, out_features=28, bias=True)
# )

# %%
criterion = torch.nn.MSELoss().to(device)

with torch.no_grad():
    pred = seq(test_x, future=FUTURE)

    loss = criterion(pred[:, :-FUTURE], test_y)
    acc = task_prediction_accuracy(pred[:, :-FUTURE], test_y)

    print("\n===== Prediction Metrics =====")
    print(f"Test MSE Loss: {loss.item():.6f}")
    print(f"Task Prediction Accuracy: {acc * 100:.2f}%")
# Out:
# ===== Prediction Metrics =====
# Test MSE Loss: 0.017049
# Task Prediction Accuracy: 14.68%

# %%
print("\nMeasuring inference latency...")

sample = test_x[:1]

# warmup
for _ in range(10):
    _ = seq(sample)

start = time.perf_counter()
for _ in range(100):
    _ = seq(sample)
end = time.perf_counter()

latency = (end - start) / 100

print("\n===== Latency =====")
print(f"Single prediction latency: {latency * 1e6:.3f} µs")
# Out:
# Measuring inference latency...
#
# ===== Latency =====
# Single prediction latency: 323430.721 µs
