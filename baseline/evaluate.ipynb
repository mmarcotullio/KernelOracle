# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: torchvision in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.17.2)
# Requirement already satisfied: torchaudio in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: numpy==1.24.4 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.24.4)
# Requirement already satisfied: pandas in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.10.8)
# Requirement already satisfied: scikit-learn in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.7.2)
# Requirement already satisfied: tqdm in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.67.3)
# Requirement already satisfied: torchviz in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.0.3)
# Requirement already satisfied: graphviz in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.21)
# Requirement already satisfied: filelock in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (2026.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from torchvision->-r requirements.txt (line 2)) (12.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (26.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/Caskroom/mambaforge/base/envs/kerneloracle/lib/python3.10/site-packages (from sympy->torch->-r requirements.txt (line 1)) (1.3.0)

# %%
import time
import torch
import numpy as np
import pandas as pd
import utils
import model

# %%
MODEL_PATH = "model.pt"
DATA_PATH = "../data/scheduling_data_out_ab_nginx.csv"

BATCH_SIZE = 984
HIDDEN_DIM = 51
FUTURE = 1000

device = utils.DEVICE

# %%
def task_prediction_accuracy(pred, target):
    """
    Computes classification accuracy of next-task prediction.
    """
    pred_task = pred[:, :, 1:]
    target_task = target[:, :, 1:]

    pred_labels = torch.argmax(pred_task, dim=2)
    true_labels = torch.argmax(target_task, dim=2)

    correct = (pred_labels == true_labels).float()
    return correct.mean().item()

# %%
print("Loading dataset...")
df = pd.read_csv(DATA_PATH)
df = utils.preprocess_data(df=df)
data = df.to_numpy(dtype=np.float32)

data_dim = data.shape[1]
total = data.shape[0]

remainder = total % BATCH_SIZE
data = data[:total - remainder, :]

seq_len = (total - remainder) // BATCH_SIZE

data = data.reshape(BATCH_SIZE, seq_len, data_dim)

train_x, train_y, test_x, test_y = utils.make_training_and_testing_set(
    data, percent_train=97.0
)

test_x = test_x.to(device=device, dtype=torch.float32)
test_y = test_y.to(device=device, dtype=torch.float32)

print("Train shape:", train_x.shape)
print("Test shape:", test_x.shape)
# Out:
# Loading dataset...
# Train shape: torch.Size([954, 1171, 28])
# Test shape: torch.Size([30, 1171, 28])

# %%
print("Loading trained model...")
seq = model.Sequence2(
    in_dim=data_dim,
    out_dim=data_dim,
    hidden_dim=HIDDEN_DIM
).to(device)

seq.load_state_dict(torch.load(MODEL_PATH, map_location=device))
seq.eval()
# Out:
# Loading trained model...
# Sequence2(
#   (lstm1): LSTMCell(28, 51)
#   (lstm2): LSTMCell(51, 51)
#   (linear): Linear(in_features=51, out_features=28, bias=True)
# )

# %%
criterion = torch.nn.MSELoss().to(device)

with torch.no_grad():
    pred = seq(test_x, future=0)

    loss = criterion(pred, test_y)
    acc = task_prediction_accuracy(pred, test_y)

    print("\n===== Prediction Metrics =====")
    print(f"Test MSE Loss: {loss.item():.6f}")
    print(f"Task Prediction Accuracy: {acc * 100:.2f}%")
# Out:
# ===== Prediction Metrics =====
# Test MSE Loss: 0.042627
# Task Prediction Accuracy: 0.87%

# %%
# Out:
# Measuring inference latency...
#
# ===== Latency =====
# Single prediction latency: 370941.650 µs

# %% [markdown]
# import time
# import torch
#
# seq.eval()
# sample = test_x[:1].to(device)
#
# print("\nMeasuring inference latency...")
#
# with torch.no_grad():
#     # warmup
#     for _ in range(10):
#         _ = seq(sample)
#
#     if device.type == "cuda":
#         torch.cuda.synchronize()
#
#     start = time.perf_counter()
#
#     for _ in range(100):
#         _ = seq(sample)
#
#     if device.type == "cuda":
#         torch.cuda.synchronize()
#
#     end = time.perf_counter()
#
# latency = (end - start) / 100
#
# print("\n===== Latency =====")
# print(f"Single prediction latency: {latency * 1e3:.6f} ms")
